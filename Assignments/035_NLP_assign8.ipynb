# %% [markdown]
# ## Q1. Download the file research-papers.csv from the link below:
# https://mitu.co.in/dataset
# This file contains the collection research papers received in different categories.
# Perform the following operations on it:
# 1. Read the file
# 2. Seperate input (summary) and output data (primary category)
# 3. Explore the output data
# 4. Prepare and vectorize the data
# 5. Cross validate the data
# 6. Build the KNN model for classification with neighbors = 6
# 7. Evaluate the performance of algorithm

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('research-papers.csv')

# %%
df.head()
# Out:
#    Unnamed: 0            id  \
# 0           0  cs/9308101v1
# 1           1  cs/9308102v1
# 2           2  cs/9309101v1
# 3           3  cs/9311101v1
# 4           4  cs/9311102v1
#
#                                                Title  \
# 0                               Dynamic Backtracking
# 1  A Market-Oriented Programming Environment and ...
# 2            An Empirical Analysis of Search in GSAT
# 3  The Difficulties of Learning Logic Programs wi...
# 4  Software Agents: Completing Patterns and Const...
#
#                                              Summary           Author  \
# 0  Because of their occasional need to return to ...   M. L. Ginsberg
# 1  Market price systems constitute a well-underst...    M. P. Wellman
# 2  We describe an extensive study of search in GS...       I. P. Gent
# 3  As real logic programmers normally use cut (!)...     F. Bergadano
# 4  To support the goal of allowing users to recor...  J. C. Schlimmer
#
#                                 Link          Publish Date  \
# 0  http://arxiv.org/pdf/cs/9308101v1  1993-08-01T00:00:00Z
# 1  http://arxiv.org/pdf/cs/9308102v1  1993-08-01T00:00:00Z
# 2  http://arxiv.org/pdf/cs/9309101v1  1993-09-01T00:00:00Z
# 3  http://arxiv.org/pdf/cs/9311101v1  1993-11-01T00:00:00Z
# 4  http://arxiv.org/pdf/cs/9311102v1  1993-11-01T00:00:00Z
#
#             Update Date Primary Category   Category
# 0  1993-08-01T00:00:00Z            cs.AI  ['cs.AI']
# 1  1993-08-01T00:00:00Z            cs.AI  ['cs.AI']
# 2  1993-09-01T00:00:00Z            cs.AI  ['cs.AI']
# 3  1993-11-01T00:00:00Z            cs.AI  ['cs.AI']
# 4  1993-11-01T00:00:00Z            cs.AI  ['cs.AI']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Title', 'Summary', 'Author', 'Link',
#        'Publish Date', 'Update Date', 'Primary Category', 'Category'],
#       dtype='object')

# %% [markdown]
# ## Seperate the input and output data

# %%
# Input data
X = df['Summary']
# Output data
y = df['Primary Category']

# %% [markdown]
# ## Exploratory Data Analysis

# %%
len(set(y))
# Out:
# 154

# %%
plt.figure(figsize=(9, 16))
plt.grid()
sns.countplot(y=y);

# %%
plt.figure(figsize=(16, 9))
sns.countplot(x=y)
plt.xticks(rotation=90)
plt.show()

# %%
df['Primary Category'].value_counts()
# Out:
# Primary Category
# math.ST               702
# math-ph               701
# cs.IT                 700
# cond-mat.stat-mech    383
# cond-mat.soft         373
#                      ...
# q-fin.ST              123
# comp-gas              114
# cs.GL                 104
# physics.atom-ph       100
# cond-mat                4
# Name: count, Length: 154, dtype: int64

# %%
plt.figure(figsize=(16, 9))
plt.pie(y.value_counts(), labels=y.value_counts().index, autopct='%2.2f%%');

# %% [markdown]
# ## Data Cleaning

# %%
import re
import string

# %%
X[6]
# Out:
# 'A formalism is presented for computing and organizing actions for autonomous agents in dynamic environments. We introduce the notion of teleo-reactive (T-R) programs whose execution entails the construction of circuitry for the continuous computation of the parameters and conditions on which agent action is based. In addition to continuous feedback, T-R programs support parameter binding and recursion. A primary difference between T-R programs and many other circuit-based systems is that the circuitry of T-R programs is more compact; it is constructed at run time and thus does not have to anticipate all the contingencies that might arise over all possible runs. In addition, T-R programs are intuitive and easy to write and are written in a form that is compatible with automatic planning and learning methods. We briefly describe some experimental applications of T-R programs in the control of simulated and actual mobile robots.'

# %%
def clean_txt(paper_txt):
    paper_txt = re.sub('[%s]' % re.escape(string.punctuation), ' ', paper_txt)
    return paper_txt

# %%
cleaned = X.apply(clean_txt)

# %% [markdown]
# ## TF*IDF Vectorize

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
X_new = tfidf.fit_transform(cleaned)

# %%
X_new
# Out:
# <53474x86480 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2836948 stored elements in Compressed Sparse Row format>

# %%
tfidf.get_feature_names_out()
# Out:
# array(['00', '000', '00000000001', ..., 'zynga', 'zynq', 'zz'],
#       dtype=object)

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, random_state=0)

# %%
knn = KNeighborsClassifier(n_neighbors=6)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
y_pred = knn.predict(X_test)

# %%
y_pred
# Out:
# array(['cs.OS', 'math.GR', 'cond-mat.supr-con', ..., 'cs.FL', 'q-fin.PR',
#        'math.GR'], dtype=object)

# %%
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay

# %%
print(classification_report(y_test, y_pred))
# Out:
#                     precision    recall  f1-score   support
#
#        astro-ph.CO       0.49      0.74      0.59       107
#        astro-ph.EP       0.56      0.85      0.68        86
#        astro-ph.GA       0.42      0.49      0.46        95
#        astro-ph.HE       0.57      0.73      0.64        94
#        astro-ph.IM       0.43      0.45      0.44        82
#        astro-ph.SR       0.45      0.47      0.46        95
#           comp-gas       0.19      0.58      0.28        24
#           cond-mat       0.00      0.00      0.00         1
#    cond-mat.dis-nn       0.31      0.53      0.39        89
#  cond-mat.mes-hall       0.45      0.68      0.54        84
#  cond-mat.mtrl-sci       0.46      0.53      0.49        88
#     cond-mat.other       0.21      0.30      0.25        82
# cond-mat.quant-gas       0.38      0.51      0.43        79
#      cond-mat.soft       0.33      0.52      0.40        83
# cond-mat.stat-mech       0.24      0.33      0.28        88
#    cond-mat.str-el       0.56      0.57      0.57        82
#  cond-mat.supr-con       0.52      0.71      0.60        77
#              cs.AI       0.24      0.45      0.32        91
#              cs.AR       0.42      0.59      0.49        91
#              cs.CC       0.33      0.59      0.42        95
#              cs.CE       0.10      0.13      0.11        71
#              cs.CG       0.31      0.47      0.37        85
#              cs.CL       0.54      0.64      0.59        81
#              cs.CR       0.47      0.58      0.52        93
#              cs.CV       0.31      0.50      0.38        92
#              cs.CY       0.30      0.39      0.34        93
#              cs.DB       0.43      0.64      0.52        81
#              cs.DC       0.43      0.53      0.47        98
#              cs.DL       0.59      0.66      0.62       104
#              cs.DM       0.20      0.30      0.24        92
#              cs.DS       0.25      0.38      0.30        74
#              cs.ET       0.57      0.52      0.54        99
#              cs.FL       0.42      0.68      0.52        77
#              cs.GL       0.12      0.24      0.16        21
#              cs.GR       0.30      0.23      0.26        77
#              cs.GT       0.44      0.62      0.52        82
#              cs.HC       0.45      0.48      0.47        98
#              cs.IR       0.48      0.62      0.54        86
#              cs.IT       0.46      0.85      0.60       181
#              cs.LG       0.28      0.29      0.28        91
#              cs.LO       0.43      0.38      0.40       104
#              cs.MA       0.36      0.60      0.45        77
#              cs.MM       0.54      0.58      0.56        86
#              cs.MS       0.40      0.42      0.41        84
#              cs.NA       0.29      0.28      0.29        88
#              cs.NE       0.49      0.49      0.49        89
#              cs.NI       0.49      0.47      0.48        91
#              cs.OH       0.58      0.38      0.46        91
#              cs.OS       0.58      0.67      0.62        79
#              cs.PF       0.42      0.22      0.29        98
#              cs.PL       0.69      0.50      0.58       110
#              cs.RO       0.65      0.60      0.62        50
#              cs.SC       0.53      0.62      0.57        84
#              cs.SD       0.42      0.65      0.51        82
#              cs.SE       0.44      0.43      0.44       106
#              cs.SI       0.43      0.44      0.43        79
#              cs.SY       0.25      0.29      0.27        73
#            econ.EM       0.31      0.35      0.33        72
#            econ.GN       0.29      0.19      0.23       103
#            econ.TH       0.49      0.29      0.37        89
#            eess.AS       0.66      0.43      0.52        86
#            eess.IV       0.46      0.43      0.44        84
#            eess.SP       0.49      0.23      0.32        94
#            eess.SY       0.31      0.23      0.26        79
#              gr-qc       0.55      0.57      0.56        99
#             hep-ex       0.51      0.77      0.61        90
#            hep-lat       0.64      0.62      0.63        86
#             hep-ph       0.64      0.55      0.59        89
#             hep-th       0.58      0.63      0.60        92
#            math-ph       0.26      0.41      0.32       183
#            math.AC       0.62      0.82      0.70        87
#            math.AG       0.48      0.39      0.43        98
#            math.AP       0.45      0.46      0.46        85
#            math.AT       0.52      0.44      0.48        89
#            math.CA       0.42      0.46      0.44        84
#            math.CO       0.60      0.42      0.50        85
#            math.CT       0.66      0.72      0.69        83
#            math.CV       0.47      0.65      0.54        80
#            math.DG       0.44      0.37      0.40        91
#            math.DS       0.59      0.44      0.50       101
#            math.FA       0.55      0.55      0.55        92
#            math.GM       0.44      0.52      0.47        79
#            math.GN       0.49      0.52      0.51        92
#            math.GR       0.49      0.66      0.56        74
#            math.GT       0.60      0.57      0.59        77
#            math.HO       0.37      0.23      0.28        83
#            math.KT       0.51      0.48      0.49        83
#            math.LO       0.48      0.61      0.54       102
#            math.MG       0.38      0.38      0.38        81
#            math.NA       0.39      0.24      0.30        83
#            math.NT       0.59      0.40      0.47        96
#            math.OA       0.70      0.57      0.63        88
#            math.OC       0.46      0.33      0.38        92
#            math.PR       0.44      0.34      0.38        79
#            math.QA       0.48      0.55      0.51        91
#            math.RA       0.45      0.35      0.39        78
#            math.RT       0.67      0.38      0.49        99
#            math.SG       0.73      0.68      0.70        97
#            math.SP       0.55      0.45      0.50        86
#            math.ST       0.40      0.67      0.51       187
#            nlin.AO       0.41      0.21      0.27        87
#            nlin.CD       0.44      0.30      0.36        87
#            nlin.CG       0.72      0.53      0.61        72
#            nlin.PS       0.67      0.57      0.61        88
#            nlin.SI       0.58      0.56      0.57        86
#            nucl-ex       0.56      0.62      0.59        76
#            nucl-th       0.76      0.55      0.64        94
#     physics.acc-ph       0.73      0.77      0.75       100
#      physics.ao-ph       0.59      0.57      0.58        81
#     physics.app-ph       0.51      0.27      0.35        82
#   physics.atm-clus       0.65      0.58      0.61        92
#    physics.atom-ph       0.62      0.31      0.41        26
#     physics.bio-ph       0.42      0.19      0.26        97
#    physics.chem-ph       0.40      0.29      0.33        73
#   physics.class-ph       0.52      0.32      0.39        92
#    physics.comp-ph       0.24      0.12      0.16        77
#    physics.data-an       0.42      0.19      0.26        85
#      physics.ed-ph       0.54      0.45      0.49        95
#    physics.flu-dyn       0.53      0.47      0.49        88
#     physics.gen-ph       0.60      0.37      0.46        94
#     physics.geo-ph       0.72      0.50      0.59       103
#    physics.hist-ph       0.75      0.28      0.41        86
#    physics.ins-det       0.62      0.45      0.52        82
#     physics.med-ph       0.62      0.50      0.55        78
#     physics.optics       0.56      0.40      0.47        89
#   physics.plasm-ph       0.64      0.62      0.63        69
#     physics.pop-ph       0.79      0.20      0.32        94
#     physics.soc-ph       0.54      0.35      0.43        91
#   physics.space-ph       0.64      0.55      0.59        76
#           q-bio.BM       0.62      0.59      0.61        81
#           q-bio.CB       0.40      0.48      0.44        82
#           q-bio.GN       0.58      0.56      0.57        82
#           q-bio.MN       0.49      0.57      0.53        86
#           q-bio.NC       0.66      0.63      0.65        87
#           q-bio.OT       0.45      0.25      0.32        89
#           q-bio.PE       0.53      0.40      0.46        78
#           q-bio.QM       0.21      0.06      0.09        88
#           q-bio.SC       0.38      0.23      0.29        65
#           q-bio.TO       0.55      0.24      0.34        98
#           q-fin.CP       0.39      0.33      0.36        88
#           q-fin.EC       0.20      0.14      0.16        74
#           q-fin.GN       0.38      0.31      0.34        87
#           q-fin.MF       0.31      0.27      0.29        88
#           q-fin.PM       0.55      0.64      0.59        84
#           q-fin.PR       0.53      0.52      0.53        88
#           q-fin.RM       0.51      0.57      0.54        79
#           q-fin.ST       0.64      0.19      0.29        37
#           q-fin.TR       0.67      0.71      0.69        96
#           quant-ph       0.61      0.43      0.50        94
#            stat.AP       0.42      0.12      0.18        86
#            stat.CO       0.55      0.36      0.44        91
#            stat.ME       0.48      0.23      0.31        86
#            stat.ML       0.32      0.14      0.19        87
#            stat.OT       0.58      0.14      0.23       100
#
#           accuracy                           0.46     13369
#          macro avg       0.48      0.45      0.45     13369
#       weighted avg       0.48      0.46      0.46     13369

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.4636846435784277

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %% [markdown]
# ## Q2. Download the file sarcasm-clusters.txt from the link below:
# https://mitu.co.in/dataset
# This file contains the collection unlabeled tweets where few are sarcastic and few
# are not.
# Perform the following operations on it:
# 1. Read the file
# 2. Clean, Prepare and vectorize the data
# 3. Build the K-means clustering algorithm with 2 clusters.
# 4. Show the tweets with 0 and 1 labels respectively.
# 5. Find and print sarcastic and non-sarcastic tweet’s top 10 words each.

# %% [markdown]
# ## Read the file

# %%
file = open('sarcasm-clusters.txt ' , encoding = 'utf-8')
sarcasm = file.readlines()
file.close()

# %%
sarcasm
# Out:
# ["It feels like just a few days ago it was the last day of school . Now it's the end of July . 😐 \n",
#  "I love my mom . No matter what we go through , no matter how much we argue , because I know , at the end , she'll always be there . \n",
#  'Bump that music ... #imtryingtosleep \n',
#  "Mexican and black jokes are pretty much the same . Once you've heard Juan , you've heard Jamal .\n",
#  'How to find work you love :\n',
#  '"@WolfpackAlan : You know what I like to do ? Answer my own questions . "" @elenecoetzer"\n',
#  'You seem like a basketball player ! — I am Thank you !\n',
#  'Just because you say Swag in every other sentence doesnt mean you have it . \n',
#  "if i had my license the only thing i'd use it for is mcdonalds at 3am \n",
#  'When people give me directions I tend to concentrate very hard on trying to look attentive and I forget to listen . \n',
#  '@pitchfork @EODMofficial WE LOVE YOU ! STAY SAFE WHEREVER YOU ARE !\n',
#  "RT Every country has an Independence Day except Britain because they're the one's everyone was seeking Independence from \n",
#  "Some days , I practice positive thinking . Other days , I'm not positive I am thinking . \n",
#  'Guys ! Guys ! Guys ! GUYS ! When we wake up we can bingewatch @JessicaJones 😈 To . Excited . To . Sleep \n',
#  "Getting gas and then I'm starting the drive back to OKC . Can't wait to be home ! Missing good old OK !\n",
#  'I love it when the bus smells like cat piss and dirty laundry ! #winnipegtransit #Winnipeg \n',
#  'Did the Meet the Press roundtable just all collectively ignore the fingerprints of the Paris attacker that came through Greece ? Really ?\n',
#  "I'm so over this bitch Sinclair glad she fell off the damn roof 😂 \n",
#  'Hearing your favorite song on the radio is more exciting than on your iPod . \n',
#  '@BarackObama @capitalweather and So ? Did you act to change something du ring your terms ? \n',
#  'Mine and @Jordyncurry texting conversation right now is so beyond serious thought its really sarcastic as well . How the hell does that work ?\n',
#  'The count with and family . #onelove\n',
#  '"me liking your selfie could either mean "" that\'s a nice picture friend "" or "" i want to bend you over a table "" but you\'ll never know "\n',
#  '"The tray is 7 "" x 11 "" with a design influenced by Mondrian . Great for serving drinks or snacks , organizing things"\n',
#  '"You took a piece of me and I let you . And that will never happen again . "" - Cristina Yang"\n',
#  "Can't wait til this weekend 😫 #OneHellOfANight is Saturday 🙇\n",
#  '@Reuters yeah there goes the dishonest media reports yet again . She is losing &amp; her e-mail scandals r revealing how disgusting she is .\n',
#  "Love means never being able to like another girl's selfie on Instagram ever again . \n",
#  '"Me - "" when do you have class "" Bay - "" uhh noon , wait no noon-thirty @Baylaaay136 "\n',
#  'My Mom says my job is to keep dad calm during the game . #challengeaccepted\n',
#  "I only shaved one leg this morning so that's how I'm doing \n",
#  'do u ever say something so bitchy and ur like damn i need to chill lol\n',
#  "you say you don't care but you can see the hurt in your eyes\n",
#  'Son : Hey dad ! I got a girlfriend ! Dad : Nice son , is she hot ? Son : Hell yeah ! Girl : Hey Dad ! I got a boyfriend ! Dad : *Loads shotgun * \n',
#  "Yay Saturday will be so much fun omg can't wait 😊 😊 😊 #sarcastictweet \n",
#  '@realDonaldTrump @AK_TWEET just admit your bald, and stop fake tanning you look ridiculous . Older men are sexy, go natural \n',
#  'Man , I love my family\n',
#  "Lol it's so funny when my dad starts racing with these other cars\n",
#  'As the sub zero temperatures arrive this weekend , make sure you dress accordingly for rides . Get those layers on and stay safe !\n',
#  'I woke up next to my girl without make up & thought I cheated on her . \n',
#  'Lol they played the warriors game at practice\n',
#  "idk how to feel about these bandwagon stans like i'm glad that J is adored by the GP again but im gonna need some of these hoes to fall back\n",
#  '@nightmare161 ... Oh YES I just did ! 😜 😁 #ImACunt #ColdBloodedBitch #Hahaha #NOT \n',
#  "@realDonaldTrump knows how to stop housing discrimination because of how many times he's committed it . Why isn't that part of his pitch ?\n",
#  "When a white girl is drunk she'll hit you , hate you , love you and suck your dick all in the same 22 minutes \n",
#  "I can't wait to be done with high school it's honestly so old\n",
#  "I wanna boyfriend who tells me I'm more than gorgeous lol\n",
#  'Taste w ur eye , ears , lips & touch 2 know deep satisfaction & understanding . Dream Peace . #JaneBernrd RT\n',
#  '@AllieGoertz Not until you feel the sting of disappointment when your roommate expresses apathy towards your favorite things\n',
#  "@KrisJenner it's cool seeing Rob on the show tell him I said congratulations on becoming a father\n",
#  'I absolutely love walking behind smokers ... #Not #YouNasty \n',
#  "@Tammileetips love how @Bertolli brings so many family's together ! Simply magical :) #MangiaMoment\n",
#  'Investigators say this van was the 3rd fire intentionally set overnight in Auburn\n',
#  'Game of Thrones teases Jon Snow return\n',
#  "I'm a better looking person with short hair but I feel like I look closer to a serial killer with it\n",
#  'WAIT HOLY SHIT TOMORROW IS THE LAST DAY OF SCHOOL BEFORE BREAK AND I HAVE ZERO TESTS AND NO HOMEWORK FUCK I LOVE MY LIFE \n',
#  'hoes so quick to jump on the bandwagon lmaoo\n',
#  "Woke up to this amazing poster of #BajiraoMastani . Love the look in Priyanka's eyes !\n",
#  'Anyways , he told me to go home first cuz he might finish late ... Boring .\n',
#  'Oh well . No sense in getting upset about it \n',
#  '@richeisen Rich , best if you stick to under water water basket weaving . Jk , love your work . \n',
#  '#Eagles backup QB Lewis looking forward to dressing on Sunday via @ThePressofAC\n',
#  "All of the best (and worst ) cars on the floor at this year's LA Auto Show\n",
#  '@ShawnMendes i think im probably gonna wake up late tomorrow but who cares\n',
#  'Lmao this shit switched sides real quick\n',
#  "sometimes it's better to lose an argument than lose someone you love \n",
#  'welcome back sinus & double ear infection . you were missed . #NOT #NOTAGAIN #GetMeOutOfHere \n',
#  "Some love stories aren't epic novels , some are short stories . But that doesn't make them any less filled with love #sexandthecity\n",
#  'Anyone else wanna let me know they got a Cardiff ticket , that would be fantastic thanks ...\n',
#  '"! "" @ginaamarieeee : Practice being cancelled would be a gift from god """\n',
#  "back in this bitch & i'm back on my shit man they tell me be humble i'm cocky as hell\n",
#  '@guardian so Hunt is hiding it , but luckily @BorisJohnson £350m extra a week brexit pledge will save the @NHSEngland , right ? right ? \n',
#  'Tacoma update and also I need to charge my phone .\n',
#  'Oldies 104 - Streaming Your Favorites ! is #nowplaying Endless Sleep\n',
#  'Seeing someone slowly lose interest in you is one of the worst things ever \n',
#  "@DCComics y'all ever think about getting Danny Phantom as a property ? I'd buy the hell out of that comic .\n",
#  '@realDonaldTrump If that means you promise to move to the UK forever and never come back, I promise to vote for you . @LouiseMensch\n',
#  "Odd #socks . Neither of which has the correct day on them . THAT'S how I roll . #rebel #oddsocks\n",
#  '"We\'re here because of riding . Riding brings us together . "" Inside the mind of a rider @HauteRoute"\n',
#  "I think the best personality trait a person can have is when they're both ungrateful AND self entitled , it's just awesome . #not 😡 \n",
#  'OMG woke up to see this . You just made my day great ! Thanx 😊 love them sooo much #DeynaForever #Nashville \n',
#  'RT Guess the country - Every city has atleast 10 engineering colleges ! Ans : INDIA *bingo * \n',
#  '"*wears a dress* "" Who you looking good for ? "" Me : no one , I was too lazy to match 2 pieces of clothing so here I am "\n',
#  '#PokemonGo has officially been downloaded more times than #Tinder . Think about that , a #game app has surpassed an app that can get you laid ! \n',
#  '#sexySaturday #happybirthdaytome #not #hurt \n',
#  "Realtree Romeo and genuine gent are literally the biggest pieces of shit I've ever seen on twitter . #NotSorry \n",
#  "If people want bareback , they don't have any problems with #HIV . Some people love #bareback . I wouldn't want it no other way . #bbbh \n",
#  'Yummy @Fruits_Veggies @VeggieGrill @ArtofEating #VegNewsletter #zucchini\n',
#  'On the bus so boring #AmericanDream #not \n',
#  'Always love sleeping in and missing the bus 😂 😂 😟 \n',
#  "The @Nissan #HeismanHouse is open at @Allstate Fan Fest . TD celebrations , OU's winners , pics with the trophy & more !\n",
#  'Ulster bank provide generous ?25 incident credit to all those out of pocket for weeks ! #sham #UlsterBank\n',
#  'World Turning by @daveydad - World/Fusion #Filmmaking #RoyaltyFreeMusic\n',
#  'I could really careless about you .\n',
#  'If you force a hocker to have sex with you is that consider rape ? Or shoplifting \n',
#  "@Tveez_World I've been on a winning streak 😊\n",
#  'Nothing like a little Biochem in the morning\n',
#  'Listen to Smoke One (Prod . by Astray ) by Hatch #np on #SoundCloud #Flaatflaat\n',
#  'Should we follow our president on insta ? #not @lorenzo_Dx hahaha \n',
#  'We have had such a fantastic day today . LO was 3 ! We had a big party with friends and family . Feeling very blessed today 😊\n',
#  'I saw a guy watering his garden WHILE it was raining last night . True story , bro . \n',
#  'I know my value and that I determine it . I can recognize when I should be great-ful and I know when someone is selling me short . #InI\n',
#  'I love waking up to shit like that . Today is already not starting off good . #hurt \n',
#  'T.G.I.M #happyworkweek #not \n',
#  'Dear Music , I will never be able to thank you enough for always being there for me . \n',
#  'about to board a flight to Vegas and taking this plane ... #myluck #not #Patriotsfan \n',
#  "you ain't gotta lie to kick it I swear ima fuck with you more when I know you keep it 100 all the time like really !\n",
#  "Late nights , early mornings . I'm up though\n",
#  'Admissions officers say & are great tools to help in test prep #prep4college\n',
#  'Cant wait to hit the gym later . Got alot of frustration to release\n',
#  'Need to release some frustration . To the Gym !\n',
#  'She use to serve this shit 😂 😂\n',
#  'Little 5 graders thinking their HW is hard ... Wait until you get into Highschool ... 😁 \n',
#  '@21andreaaa oh , defiantly ! Even though I know how much fun you had .\n',
#  'Not even mad I dropped $256 preordering the iPhone 6 to have it Friday morning at 9 am ... Hard last week in iPhone 4 gang #not \n',
#  "most hilarious interviews ever XD you're really awesome ! by the way my bro the best ! xoxo\n",
#  '@ImOnlineLol please fav . Then reply\n',
#  'HAPPY BIRTHDAY @Michael5SOS #MichaelClifford #HappyBirthdayMichael\n',
#  '@harrymoonavenue I thought my tv was being dumb lol\n',
#  'I just spent like an hour destroying my hair by curling it then realizing it looks bad so I straightened it \n',
#  "@Only1dri I wish I would've recorded the shit I just seen in AOS smh . Shit was trife \n",
#  "RT Removed 'Punjab ' from udta punjab Reason : punjab ni udta ... #chidiya udao \n",
#  '"Don\'t make fun of me because I have a problem with keeping my blood sugar low . You\'re suppose to be "" college ready "" . "\n',
#  "Ok you hoes you can stop now everyone knows you're just a bandwagon & dont give a shit about soccer 😧\n",
#  "Worried about politics but already stressed over life don't need more stress about who's going ruin this country\n",
#  "RT If you can't change the girl . Then change the girl . - Saying single . \n",
#  'If you want to get caught up on the awesome SL going on in Marvel RP right now , pick an issue and read !\n',
#  'Great article on building a Real Brand that Builds a Better World by @KarenDellCMO @Dell\n',
#  'If your having a bad day , watch my mum x\n',
#  'It says it all about me right now #LivingTheHighLife #Not ! \n',
#  "Lmao cuz that's attractive . Do something productive\n",
#  'Fun Upbeat Instrumental Music - Royalty Free Music For Video , Presentation , Commercial : via @YouTube\n',
#  '@TIME One could lend a lot to the Clintons for his state of affairs, giving advice that no one can get .\n',
#  'I pretty much hate being sick more than anything\n',
#  '@threestangtyry @BuckeyesCubs10 hahaha . So not funny ! #SarcasticTweet \n',
#  'I miss being called Shasha .. One reason why I love being around my aunt \n',
#  '@ElijahAbdo @Zen_MasterFlex @leomillan27 @nflnetwork @Jaboowins @TBBuccaneers I said he was good too Bruh u foolin\n',
#  'lemme stop spamming now and attempt to sleep ... or nap at this point ugh . \n',
#  '@camerondallas You is world : 🌎 My is world : Cameron Dallas\n',
#  "@KatelynCronk not really it wasn't intended to be racist . It was intended to make fun of James , and it was an inside joke \n",
#  'This is a great video for #preschool classes and children will love this . \n',
#  'Looking forward to visiting Z Coy Trg weekend at OTA tomorrow morning . Good luck to our Bde team at the National football & all other events\n',
#  'On the bright side i only have 3 more exams to sit and then summer break :)\n',
#  'NOT Arsenal , not Manchester City and certainly not Chelsea . Leice\n',
#  "My teacher told me i wasnt go B shit cuz smoke 2 much weed Crazy cuz i passed her class wit a B She just didnt like me cuz i hang n the st's\n",
#  '#ExMuslimBecause I loved my friends that were kuffar/infidels How could it be right to hate them just bc I was told to ?\n',
#  '"@mawmawshelley I hope you are not getting the COUGH I have coughed all day long/ can "" t wait until tonite/// "\n',
#  "@_ac616 so you're feeling good about OU's chances ?\n",
#  'Dumb Woman Live Streams Herself Drunk Driving #arrested #drunkdriving #dui #dumb #fail #foolish #funny #lol #wshh\n',
#  'Literally had to delete all my apps to download this IOS 8 . 😕 #notworthit \n',
#  'I did it . I TED talked . It went really well . No awkward silences . People laughed . SO RELIEF . VERY ACCOMPLISH . WOW .\n',
#  'Help ! My #OCD is kicking in ! They are having a blast so I must walk away & leave them to it ! #kids\n',
#  "Carbonated soda now relieves cough , scratchy throat , sore throat , and congestion . I can't wait for cherry-flavored Coca RicCola . \n",
#  '"@idreamsilvia thanks ! It was great , though I\'m kinda bummed to be home now . Philly is just kinda "" eh . """\n',
#  'What makes a negative review on #Yelp any worse than a negative post on any other social media site . #Tripadvisor #Reddit #Bueller\n',
#  "can't wait to get out of highschool\n",
#  "@HillaryClinton Trump has paid women equal pay for 30 yrs . Why won't you ?\n",
#  '2 minutes of extra sleep in the morning seriously does matter . \n',
#  'Girls With Hot Guns & Sexy Garter Tattoos\n',
#  "@edsheeran's Kiss Me has been playing in my head all week long .\n",
#  "It's funny how I'm the 1 with the full time job while ur home sitting on ur #fat ass BUT I have to keep up contact #not happening again ! 😡 \n",
#  'First day of school . #yay\n',
#  'School for 6 hours and then work for 6 hours #soexcited #not \n',
#  '"Prentice\'s cabinet of "" regular "" Albertans - Notice the traditional Albertan bow tie #not "\n',
#  'Lol . Not anymore . Too fucking hot down here . I miss layers ! 😢 😢 😢\n',
#  'I just love how people try to tell me how I should feel . #not \n',
#  "@HillaryClinton most people don't even know what I pull pack operator is let alone drive one how are we not a skill job Makin over 20 a hr? \n",
#  'RT avoiding water spots while walking in socks is toughest thing ever -_- \n',
#  "Dear vegetarians ... If you're trying to save the animals , why are you eating their food ? \n",
#  'Learn more about healthy , #sustainable living ! #bostoneco\n',
#  'My ex boyfriend heard of At Sunset through his cousin . Lol . What a coincidence seeing as not many people in the UK have heard of them\n',
#  'liam said theyd be working until the end of the year and their last planned event is the 10th but still i doubt they love me enough \n',
#  'Love being left alone ... Just me and my thoughts \n',
#  'So why are lads popping up to me that have just had a baby #getagrip #not interested \n',
#  "I don't want to ask because I'm scared of the answer \n",
#  '@megynkelly and I also would get upset if I was not able to finsh what I was saying you need to wake up\n',
#  '@HillaryClinton Your words only add up to mafia mainstream indoctrinated media . 🤗 😘 😘 😘🤗 Amb Stevens words added up but u ignored him . \n',
#  '"Let\'s be weird together "" I think weird is an understatement"\n',
#  "My boyfriend's face is so gorgeous . From his brows , eyelashes , lashes , to the shape of his face , etc . I just love it 😊\n",
#  '#Esteban is #not a name u want ur daughter dating . #oyVey \n',
#  '@__Tinyxx CONFRONT means you coming face to face hostile tryna start an argument . Use yo words correctly boo \n',
#  '@BarbaraPalvin you should make a q&a w us or maybe a follow spree\n',
#  "You'd think I was wanted for murder or something by the way I react when someone rings the doorbell 😒 \n",
#  'Somebody want to explain #notyourshield to me ? So far I have literally only seen it used by egregious sock-puppets \n',
#  "Is it chill to go up to a stranger and say 'you look cool do you want to go get drunk with me '\n",
#  'Interesting pd literature . Seems like teacher choice is so needed #sceduchat #tosachat \n',
#  "FUCK liars . FUCK cheaters . FUCK fakes . FUCK players . FUCK hoes . FUCK bitches . FUCK .. everybody that's not REAL\n",
#  'These kids were asked to slap a girl in front of them and they said no ❤️ 👼\n',
#  'In order to help others , in order to serve others , the real motive is love . \n',
#  "There's literally nothing to eat in my house but cheese burger hot pockets .. Mmm how gourmet . \n",
#  "I'll find a way to get to youu ' ?\n",
#  'Damn , girl , are you Terms and Conditions ? Because I just want to blindly agree to whatever you say . \n',
#  "El Classico , I'm A Celeb and tea ☕ tonight 😊\n",
#  '"biatch , i love food . why u no love food ? "" "" because i love u whattt "" kembang aqu HAHAHAHAH"\n',
#  '"Sanders Claims CBS Canceled Agriculture Interview Because Monsanto Was "" Threatening To Sue "" - BuzzFeed News"\n',
#  "@S1Moo_96 You're welcome ! Yes , i hope to see the match , because i don't know if i can . 😕 Thank you , we'll give our best to remain on top . 😄\n",
#  'Watching Pretty Woman on this beautiful Sunday .\n',
#  "Surely not right ? ... but I'd bet it is\n",
#  "Go to college they said . It'll be fun they said ... #not \n",
#  '@beatbox1872 @yvpotts maw mate but I saw him , he was outside !\n',
#  "The older I get , the more I come to realize that I just don't care what the hell anyone thinks . \n",
#  '@ConnorFranta I love being up early bc productivity but also I love sleep\n',
#  '@DanielAllman aha omg I remember getting wrong for Royah copying me haha she literally only used a sentence #notthatdeep \n',
#  "@CNNPolitics @DaniellaMicaela Wasn't long enough or falic in appearance? Made in China Donnie! #trumpisatraitor #TomthetraitorCotton \n",
#  "We've been busy working with some great brides ! Check out our new photos on #TheKnot ! \n",
#  'Almost every college student will come home for break and be ready to go back to school soon as our parents start tripping 😂 \n',
#  'I am super excited for @nbcsnl tonight ! @Adele is going to be amazing !\n',
#  "This year I'm determined to enjoy the festive season 🎄🎁☃🎅 decorations always make me smile ☺️\n",
#  "My tweet wasn't really about you . But if the shoe fits , then lace that bitch up and wear it . \n",
#  "He looks so creepy there . I swear he's not actually creepy #superswankparty\n",
#  "There's literally no food in my house & my mom wonders why I always buy food before I come home 😒 \n",
#  "RT You can't travel to space with the money you have . But you can buy a bag full of weed and that's kinda same thing bruh ! \n",
#  'I think i need a #theoryofadeadman intervention . Literally been listening to them for 2 weeks straight . #sendhelp #notreally @TOADM \n',
#  'Al Green-Lets Stay Together:\n',
#  "@Drake I'm happy for you you've been waiting her to love you for 7 years now she has a forever tattoo only for you\n",
#  'Gets a text* ... *Grabs Phone* .. *Reads Name* ... *Puts phone back down without replying* \n',
#  'LOL @NERO IS SALTY #GAMERGATE #FAIL #WARRIOR\n',
#  "@ddlovato we still love you! And it wasn't offensive people are just extra af\n",
#  'Love . @xkcd via newyorker \n',
#  'I love learning about new or past things in sacred geometry \n',
#  '@yGrizeh safeguard its prob my favorite aside from kill confirmed\n',
#  'RT Interviewer : One thing u r good at ? Me : Doing Miskates \n',
#  "@nytimes Because there isn't going to be one world government most people don't want that we want borders ! Hey liberals kiss my ass !\n",
#  'Love it when @abbiewilkinson7 @abbtweets me and then deletes it . #not #bitch \n',
#  '"@realDonaldTrump ""victory"" party at Hilton - of course - he doesn\'t want to LOSE AT TRUMP TOWER https://t.co/irdRcIgLLx "\n',
#  "Haven't been able to sleep , so I've been playing Words With Friends and Angry Birds all night . What a thrilling life I lead . \n",
#  "@ColletteWalsh @BBCNews thanks Collette , I'm afraid to say I've never worked at channel M ... I thought it was great though and is missed .\n",
#  'Bitches have no shame 😂 😂 😂\n',
#  'hate this class\n',
#  '@TXHSFB looks like @SGPNation will be breaking another winning streak ! #SGPBEATDENTONRYAN\n',
#  'Yay I finally registered for the classes that I want to take next term 😊 .\n',
#  '"@bayafay :57 days "" party in the USA 🇸 #NOT "\n',
#  'Driving to Manchester , topic of conversation - Who names hurricanes and why do they have normal names ? #deepthought\n',
#  "Nobody really cares if you're miserable , so you might as well be happy . \n",
#  '@Smido11 better question who closer to getting the Haye fight , Smith or Nelson ?\n',
#  '"im glad dogs cant read the "" no dogs allowed "" signs so they dont feel sad & left out "\n',
#  'All I want to be doing right meow #fail #vine #failvine #lol #aw #omg #lmao\n',
#  "I can't wait until I can drive to make sure I get myself to dance class on time #homealone \n",
#  "I'm amazed at how far guys will go to try to make me jealous . My ex is married now with 3 kids -- I see right through that . \n",
#  'And I should make clear that everyone was about 10 levels above me ... Quite an impressive feat I think\n',
#  'FNV Live Brings Together Celebrities , Companies and Athletes for a One -of -a -Kind Celebrat ... #entertainment #news\n',
#  "Yay , get my wisdom teeth out tomorrow ... I'm so excited . #not \n",
#  "@heroesfanfest will there be free wifi in the convention center ? I CAN'T WAIT FOR TOMORROW !\n",
#  "@mattgoss Hi King Matthew , I'm Sure U , Sir Lancelot , Sir Galahad & Cool Hand Luke if he's/w will hve an Amazin day cuz ur Bless by the Best :)\n",
#  "Lab better not last the whole 3 hrs tonight . Going to tell my TA I can't stay because I have to go see the Hunger Games . \n",
#  'Nissan News : Smooth operator : All -new Nissan NP300 ... #Nissan |\n',
#  '@realDonaldTrump @nytimes see? Words are killing .. there is 1 Zero Nero that buttons the strings . per top below . 8=20 #Herzproblemsin26=14 \n',
#  'So in love I could puke \n',
#  '@ovi8 One more year and you will have to stop that ... #not \n',
#  '@YouTube gave me a strike for no reason . @Plexity_YT @MrShockzYT . - .\n',
#  'and im getting hungry when my lunch time is coming to an end\n',
#  '@MaterialHndling You definitely have a great one , too . I am looking forward to a big meal football and hockey ! Oh , and naps ! Def Naps !\n',
#  "#selfiesfornash don't get blind bae  #kidding \n",
#  '@faniii_stephooo lmao , so you know its real\n',
#  '"New favorite term — "" disappointment districts "" — and quote — "" Someone decided to throw out the scale . "" "\n',
#  'RT hey where have you been all my life ? Can you pls go back there \n',
#  '@NICKIMINAJ I love her as much , baby I only gave her a little something for her performances and stuff and shoots and stuff .\n',
#  'Ehh why not run another one back .\n',
#  'laying in the dark with my headphones in 😊\n',
#  'My life is #sarcastically #sarcastic \n',
#  '@itsjamesgraham Holy Shit James 😍 😍 😍 😍\n',
#  '@nytimes Better watch for cartels who can launch mortar attack . These guys are well armed these days &amp; they hate him .\n',
#  'Honestly ignoring me is the worst thing you can do to me . \n',
#  "Quite an impressive crowd at #woty2015 . Congrats to all of the women who are leading the charge in Atlanta's IT community .\n",
#  '#Nowplaying 2 Chainz - Jump (Explicit ) #360WiseJamz #Rap -n - #Trap #Indie #Major\n',
#  "@CarolineZwick I've never heard that one before . #ihearitallthetime ? \n",
#  "@JoeyGraceffa I'm so proud of you , everything you have been doing is so high quality and amazing . I love you so much 😊✨💖\n",
#  '? Yes dad I love to hear you sing in the morning #Pleasecontinue \n',
#  "#Bullshit Might Get You To The Top , But It Won't Keep Yo There . So Ma Niqqa , Drop Dah #BullShits #TeamNoBullShits #SwaGKinz\n",
#  "I updated my Mac to the latest software and now it hardly works so that's awesome 🙁\n",
#  'RT , FranklinSaint : #cantwait #starwars #theforceawakens #countdown #wereisluke #TFAStarWars #StarWars #StarWarsRTs\n',
#  'You all laughed at me when I put macaroni in my pockets before the game , but I laughed at you when I ate it for a snack at halftime .\n',
#  '@megynkelly watching CNN attempt to discredit TRUMP is becoming hilarious as their attacks are so so foolish, illogical, and irrelevant \n',
#  '@kenpootCFC see you later enjoy the game :-)\n',
#  'Had so much fun at Stages Last night . @MLinton_7 @_katcoat Sister Christmas Catechism it was so hilarious\n',
#  '@LightskinLexi_ foreals that shit was fun af !\n',
#  'We lost Jabba , our botia fish today . I mean literally lost him . We have been unable to find him , any sign of him . #aquarium #nottalking \n',
#  'holy shit i havent updated my drivers since i built this computer in february lmao\n',
#  "Went to take the trash out and noticed winter is approaching . I hate the cold #Noooooo #I'm #Not #Ready \n",
#  '"When I was a kid they didn\'t call it "" Behavioral Disorders "" , They called it "" Being a little brat "" . "\n',
#  'Use y =mx +b to calculate the slope of how down hill my life is going \n',
#  '@PJackson__ i only have 30min lunch break though so i may as well drive back home grab soup or something and come back .. bank is always busy \n',
#  '@CNNPolitics Sage advice from the Tell it like it is guy Those of us that Love and Trust Hillary knows her Heart and wants America to see it\n',
#  'January 2013: This will be my year ! October 2013: lol \n',
#  '@ChrisABiersack love this cover so much . Looks like an awesome band family of rock n roll brothers 😄\n',
#  'Literally rolled out of bed at 5:45 today . Looking extra ratchet . #notasinglecaregiventoday \n',
#  '@sunlorrie the way they voted in the province I would have a full investigation ! #sarcastictweet #wynnesanity #onpoli #olp \n',
#  "That awkward moment when kids see a toy they want on TV but they can't get it because their parents must be 18 or older . \n",
#  'Son if you play with my bestfriend then you playing with me\n',
#  "We Don't Fuck With Police Broski\n",
#  'stop worrying about shit that doesnt have anything TO DO WITH YOU \n',
#  'is there anything worse than hearing your own recorded voice i think no \n',
#  "RT Why twitter can't exist in Game of Thrones universe ? Because all the 140 characters will be killed . \n",
#  '@EvertonMoaner this is twitter not school no need for propar grammar fag . \n',
#  "I don't know which face to talk to , since you have two . \n",
#  'Beautiful day out! \n',
#  'Wooooo ! Eleven hour days ! #Not \n',
#  "He sucked it like it is a very fine desert he's determined to enjoy . Hi , Logan ! hahaha !\n",
#  '@realDonaldTrump Please be calm in the debate tonight,you gone crush her . She has nothing to show for after 30 years in the public office . \n',
#  "Hey 💎 I love the album so much ! Can't stop listen to it ! Thank you @NiallOfficial #1DNiall #MadeInTheAM \n",
#  'Weston looks sweet with that hat backwards . #not \n',
#  "#Glenn's fate revealed on 'Walking Dead '\n",
#  'Want to see us Fuck ? #liveoncam #camgirls #livesex #sexcams #ass #porn #milf\n',
#  "I'd kick you in the vagina but i'm afraid I'd lose my shoe . \n",
#  'Belated happy birth day lols — Thank you !\n',
#  'Batting 1,000 today ... #waytogochamp #not \n',
#  'Happy #TGIF ! Oh , how I ❤ @AndriaMusic #soul #voice . #Obsessed much ? YES ! Check out her #new #cover #BillsBillsBills\n',
#  "Courtney why u arguing with them ? 😂 We know who the best is . No need to explain 🅿️ . Knowing how 2 dribble and shoot doesn't make u the best . 😕 \n",
#  "@guypbenson There's not link between Paris and the Algerian arrested confirmed or even likely . Obviously a poser . @KySim @JuddLegum\n",
#  'I just casually lurked through @KhadiDon videos 😭 laughed for at least 15 minutes\n',
#  '"Kindness is never wasted -- an intermittent "" thank you "" here and there is simply a nice perk . "" ~ Dr . Colleen Georges "\n',
#  'Its been a rough month ... #sick now #single and #failed at my #dreamjob #chickensoup for my #cold and #psiloveyou for my #soul #chickflix 😓\n',
#  'no but a school bus full of children almost did\n',
#  'USA NEW DEALS #667 Decorative Wine Bottle Umbrella Folding Portable Sun Rain\n',
#  '@RosieHW @hungvanngo GOD DAMN GOD DAMN YOU ARE THE MOST INCREDIBLY BEAUTIFUL WOOMAN IN THE WORLD GOD DAMN I LOVE YOU 😘 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍 😍\n',
#  'Being hydrated is great , but at what cost ? ! Nothing like waking up from a deep sleep to pee then not falling back asleep . \n',
#  "The sound of children laughing makes me happy . Unless I'm home alone and my power goes out . \n",
#  "i can't breathe out of my nose and my phone won't turn on . today is gonna be such a good day ! \n",
#  "I'm so glad I met you in middle school at a party ! Geometry last year with you was bomb . Love you !\n",
#  'And their TV and Films are in separate universe which is dumb to me\n',
#  'Wtf is wrong w this bitch\n',
#  "There's nothing like the smell and feel of freshly washed sheets\n",
#  'Nothing like having your entire body in pain before band . #thiswillbefun #not \n',
#  'I literally go grocery shopping to relax . Nothing is more calm to me than a three hour trip to Walmart . #notbeingsarcastic \n',
#  'I could careless about you kid\n',
#  '"to the people "" whispering "" non stop while i\'m trying to learn . you are not as subtle as you think you are . please stfu ."\n',
#  '#cute #cats Between shadow and light #yummypets #european #cat\n',
#  'I had a pretty great day even with it starting out with an exploded pen 😂 \n',
#  'Yay for not having a ride to school \n',
#  'Happy birthday to one of the only freshman I can handle and a pretty awesome baseball player 💙\n',
#  "my grades aren't that bad for someone who has the urge to drop out of school every 25 minutes \n",
#  'ToMiho is my kind of perfect relationship . #ShowtimeKiLigContinues \n',
#  "It's socially acceptable to believe in a god , and everything that goes with it , but not aliens . \n",
#  'Im Not Looking For No Type Of Relationship But If A Girl Who Keep It All The Way And Can Hold Her Own Comes In My Life Ima Keep Her\n',
#  '"@realDonaldTrump stop acting like a spoiled brat . ""It\'s rigged"" . Such a cop out . You are a poor loser . Emphasis on LOSER ."\n',
#  '#Cyclones need to show something here .\n',
#  "Do you work at Little Caesars ? Cause you're hot and I'm ready . \n",
#  '"What\'s all this talk about "" Mayweather ? "" Guys , this is FALL weather ! "\n',
#  '@_tiffanytaylor @onedirection please tell them that I love them so much ! And please follow me back on Twitter . Hehehe 😭 😘 😘\n',
#  'last day of work and im fucking late\n',
#  "@S444_RMO just Sheffield , S6 isn't London ... Thought about Holmfirth but came up too quickly , last Saturday was great though\n",
#  "@mangouji it is tbh And I love the band teacher honestly he's great AND I'M GETTING CREDITS FOR DOING NOTHING LIKE ? ! ? ! ? \n",
#  'Correction Pussy . ! Pussy keeps the world spinning .\n',
#  "I'm too high to give you a hug , can we have a meaningful stare ?\n",
#  'If you go to dinner alone always ask for a table for two . Look sad as you eat and you will almost always get a free dessert \n',
#  "As #strictlycomedancing is in #Blackpool I've had a chippy tea tonight 😋\n",
#  "😘 @kmichelle thanks for being the realist ! I'll forever support #Rebel\n",
#  '@thatgalkabzee ohh nice ... lemme charge my phone x eat up\n',
#  "I want to stop drinking ... but my mom didn't raise a quitter ! \n",
#  '$elr - spdr dow stock analysis - day trading option -\n',
#  "Bored , so I'm going to find a kid that looks like me and tell him I'm him from the future . \n",
#  'Birthday gift from maldonado . julian :D ! #harrypotter #thecompletecollection #books #yay\n',
#  '@Raghad_abubakr I knowwwww =)) !\n',
#  '@BBCNews for now-Grayling Omni-shambles bearing fruit of the forlorn &amp; destitute who are roped in with criminals-prison service implode\n',
#  'Just finished my last Chem lab of the semester . Yay , another 3 hours a week to waste time on the internet ! \n',
#  '"i\'m not the "" cute "" awkward im the "" what the fuck is wrong with you "" awkward "\n',
#  '"Now Playing : "" Doin \' What She Likes "" By "" Blake Shelton "" is on Q106 . 8 Country"\n',
#  'Mario is definitely homeless . He wakes up every day wearing the same clothes , runs around in sewers , beats up people for their money \n',
#  'Breathing feeling good this morning\n',
#  "Pretty unsettling that we're a few years away from having doctors that are either firmly team edward or team jacob . \n",
#  '@HIRomanceReader Thanks for following back !\n',
#  "Can't wait to hear @LittleMix perform secret love song pt 2 live 3 that'll be the day\n",
#  'Me : ill do my home work at 3 *clock says 3* Me :\n',
#  "What's nice about kendra friendship he ask her opinion and what she think in the GA story aw I cant wait for San & Kev pic together :)\n",
#  "Don't know what to have for my tea 😫 #hungry #nothungry #food\n",
#  'The grass is not greener on the other side . The grass is greener where you water it . @petervoogd23\n',
#  "@HillaryClinton Too bad you're not moved enough to drop out . \n",
#  'Here she go again ... waking up looking at me tweet , gets mad , and falls back to sleep ! 😂 Like YOU keep falling back to sleep 😂 & waking up\n',
#  'Joker is really one of the best villains of all time\n',
#  'I hate waking up sick 😷\n',
#  "Never trust a married guys opinion of who's hot . It's like asking a starving guy what food tastes good . \n",
#  '@l0uisagilchrist happy birthday x\n',
#  'Always lovely when the sisters home for a visit\n',
#  '"Girls who say , "" a lot of guys are after me "" , should keep in mind that low prices always attract many customers . "\n',
#  "After roughly 5 months I'm finally cleaning my room 😅 \n",
#  "look I love talking to jerks about shitty 90s WW rpgs , but I'm never going to talk to someone simply because of that shared association\n",
#  'smokemerazor : home :) we miss you sunflower ~ still ... - #Hot #Cool or #Not ? #Cannabis #MarijuanaPics #WeedPorn \n',
#  "@selenagomez i'm proud of how humble , caring & amazing person you are . You inspire me to become better & be a stronger person , I love you .\n",
#  "My girlfriend told me she wanted me to surprise her with a gift that will take her breath away . I'm thinking about getting her a treadmill . \n",
#  'Lotus Dickey - Yellow -Eyed Cat #oldtimemusic #nowplaying\n',
#  "Today's food intake with 2 litres of water & 2 green teas #healthy #weight #loss #fit #not #skinny \n",
#  "@realDonaldTrump another innuendo seems to be a pattern I'm not saying but I heard people talking \n",
#  'Got 3 CDs of today for 50 % off from via US only sale ! I can never find their albums at a good price . #bestdayever\n',
#  'RT proud moment when you catch a mosquito in your first attempt \n',
#  '@EmbryBrooks I guess I got one more week to at least be half right 😉\n',
#  "Woke up ... Came to my 8am ... It's canceled ... Thanks for the notification AFTER I was up \n",
#  'When #hypocrites hate on me , it does #NOT make me want to return to theism ; it makes me really glad that I got out . #Atheist \n',
#  'Premium Semi -Loaded Caliper fits 2004 -2013 Nissan Quest CENTRIC PARTS\n',
#  'Looking forward to going to my first Virginia Tech hockey game Friday night ! #hokiehockey\n',
#  '#cubuffs hoping to slow down Wazzu passing game tomorrow night :\n',
#  "@CNN Hold up they don't love you like I love you slow down they don't you like I love you .\n",
#  "So cold I'm gonna attempt to sleep in pjs ! Any screaming , don't panic it's just me waking up twisted in my clothes ! \n",
#  "I've completed Ready for the Journey collection ! #ipad #ipadgames #gameinsight\n",
#  "Nothing a smile can't FIX . Not even tissues ? #not #abnegation \n",
#  'Oh how I love getting lost in Bridgeport 😅 #not \n',
#  '"The speed in which a woman says "" nothing "" when asked "" what\'s wrong "" is inversely proportional to the severity of the b*tchfit that\'s coming . "\n',
#  '@realDonaldTrump @HillaryClinton ... I am not as concerned with the drooling 😪 dummy as I am the folks trying to carry her to the white house\n',
#  '#OFuxico - Jennifer Aniston confessa ser fã do reality Keeping Up with the Kardashians - #notícias \n',
#  'because i have nothing to do\n',
#  'Lady at @Sephora said I was really pretty . Made my day . ☺️\n',
#  'Rise Against was great though .\n',
#  'I unlocked the Night Owl sticker on #GetGlueHD !\n',
#  "As much as I love bargain hunt of a lunch time , it's so hard to not fall asleep to it\n",
#  '"And all the kids cry out "" Please stop you\'re scaring me "" I can\'t help this awful energy Goddamn right , you should be scared of me"\n',
#  "The fact that I just turned down a shift at work because I'm stuck babysitting my siblings really making me sad \n",
#  'Luv waking up early to go to doctors offices \n',
#  'RT If I wanted to kill myself I would climb into your ego and jump into your IQ . \n',
#  'Fascination by @cstarkprod - Electronica #Filmmaking #RoyaltyFreeMusic\n',
#  'Trying to find some classy shirts & literally everything is a crop top #ew #NotIntoIt \n',
#  'if I watch Battlestar Galactica and skip the very end of it , Laura Roslin lives , right ? Confirmed ? @BSGmuseum confirmed ?\n',
#  'When the sun goes down you can rest your love on me \n',
#  'Can I get a scholarship for eating ? \n',
#  'hiddenlove #sex #sexy #horny #pussy #ass #booty Watch Live Sluts\n',
#  'I will but not right now\n',
#  '"Hoes be like "" hoes be like "" but they be the hoes that be like . "\n',
#  'I agree with 30 % ... Maybe more .\n',
#  'That jingle is pretty catchy ... #not #wweraw \n',
#  'happy birthday kat ! i hope your day is as amazing as you are @KattAracic ilyyyy\n',
#  "@CNN After tonight Trump will be clear winner . Hillary can't explain away corruption, her lies &amp; letting our men get massacred in Benghazi \n",
#  "That's yo main shout out to her brain that lil nerd bitch\n",
#  'Do you want #government taking practically everything from you , or doing practically nothing and letting \n',
#  "@narrycosmo crete , its soo beautiful there ! and if you come to norway you'll be shocked by how cold it is lmao\n",
#  '@SnarkLunge Love ya Sex Pistol ! Sleep well tonight hun ! Have sweet , sticky dreams ! Hehe . 😘 ❤ 😘 ❤ 😘 ❤ 😘 ❤\n',
#  "I love back and forward convos where there's no awkward silence\n",
#  '#omg 👋 What Secrets Hides Your Birthday ? ==\n',
#  'I lost AJ Green and Jamaal Charles from the same #FantasyFootball team on Sunday , Maybe my tight end puts up 40 points #yeahright \n',
#  'Just so everyone knows , @ADeVaney30 is the proud owner of a pair of Skechers #shoegamestrong #NOT \n',
#  "I don't care about this dumb show I'm gonna go watch cute boys kiss each other \n",
#  'and its like i dont WANT to be u know ... i wish i could trust people but the last 2 ppl i opened up to are shit and every cis guy hurt me\n',
#  'When u drink too much and fuck up every good thing that ever happened to u\n',
#  '"Bros before hoes "" is something a bro without a hoe would say . "\n',
#  'i was SO excited for thxgiving break untill i got my schedule today and found out i was working 41 hours nxt week and only have 1 day off \n',
#  'Well . What a surprise #not \n',
#  '@Real_Liam_Payne you guys truly deserve it , thank you for the great music :) #CongratsOneDirection #1intheUk\n',
#  'What do you call a gay dinosaur ? A megasore-ass \n',
#  "I'm glad I am such a big part of the team\n",
#  '#SNL Wow ! The best episode in a long , long time ! The best opening ever ! Thanks !\n',
#  'My mood switches from happy to sad in an instant 😔\n',
#  'I said it b4 ... Anger & hate is like pouring glue where oil is needed . They will slowwwwwwwwww you dowwwnnnnnnnn .\n',
#  '@Marijke51 @deneb58 ah well - time for a cigarette break - fighting gods with a small bit of plastic is tiresome but necessary , ok ?\n',
#  "why am i already planning my 27th birthday trip i have like 7 years to wait but right now i'm really digging the idea of greece \n",
#  "I didn't forget , it just slipped my mind when I could say something . Happy birthday .\n",
#  "@AwayDaysYT Clearly just didn't have the attitude or work ethic to make it at the top level . Shame , as you say\n",
#  "Jerrie -Secret love song/Grown -Pretend It's Ok/ Love drunk -These four walls/Move #MTVSTARSLITTLEMIX\n",
#  '@Beyonce you are such a sweet chicken nugget and I love you baby marry me\n',
#  'Nice to be back home for the weekend\n',
#  '@stonecypher @TheHorrorMaster Me too - should be great !\n',
#  '@MileyCyrus @HillaryClinton liked u when u took ur clothes off, at least it hurt you &amp; not others .\n',
#  'i swear i suffer so much with this performance\n',
#  '"@Mizzblueshirt u know I\'m right and you\'re annoyed that I called you on it . caption should be "" great cleavage day """\n',
#  'i wonder who im going to marry one day like who is gonna keep up with me wow \n',
#  "I'm going to start responding to videos people post of their babies on Facebook with videos of me getting nine hours of sleep \n",
#  'Late nights , early mornings #ThugLife 😩 😩 😩 #iGuess\n',
#  '@katerose511 you should try throwing school into that equation ... it makes things so much more fun !\n',
#  'Its lunch time and im not hungry at all . This isnt me 😕\n',
#  "🌺 You're gorgeous and you and your boyfriend are soooo cute !\n",
#  '#DNWkndRU : Saturday :3 . Bowman Volunteer Fire Dept Boot Drive , 11 a . m . -3 p . m . , Chevron gas station (former Texaco Starmart ) 19845 Main St . ,\n',
#  'Buds 420 - #Hot #Cool or #Not ? #Cannabis #MarijuanaPics #WeedPorn \n',
#  "Some people just normally look like they haven't slept in weeks . I am one of those people . #Insomnia #Not \n",
#  'Our incredible members ready to brave the freezing temperatures ! #challengeaccepted #bravery #ThisGirlCan\n',
#  "So awkward when you need to flick a fag and there's someone sweeping up fag butts . \n",
#  '@KFC_UKI Yep just like the advert ! #not \n',
#  '@cupcakemila HAHAH TRUE I FORGOT THAT WAS A THING IT WAS GREAT THOUGH\n',
#  '"One Direction can\'t sing "" Yeah . Ok . Next lie please ... #MTVSTARS One Direction "\n',
#  'I get back to the dorms right when they let people back in from the fire alarm . Perfect timing . \n',
#  'THE COST OF AMBITION °LATE NIGHTS , EARLY MORNINGS °LOTS OF ASSOCIATES , VERY FEW FRIENDS °YOU WILL BE\n',
#  'I just want to lie in bed and not participate in life \n',
#  'Doing laundry at night nothing better ! #not \n',
#  'Back to work 😒 #yay  \n',
#  'A must hear for anyone struggling with the noise of busyness to learn to discern what we should give our best Yes\n',
#  '@spacecoreV8 it really depends for me . Sometimes it makes me feel great other times pure rage \n',
#  '@PrestonSteve933 @prestonelliot I am pretty sure I have #DeadGuyInAnEnvelope now I just need to get threw on #monday #gottawantit #sneaky\n',
#  'The only reason they make yellow starbursts are for when someone asks you for one . \n',
#  'Scholes , Fowler , and Dixon as a panel ... Top personality contest there ! #not \n',
#  '"A woman without her man is nothing . "" but a WOMAN , writes it the correct way : "" A woman ; without her , man is nothing ."\n',
#  'Dear USA , please stop remaking brilliant television such as #TheReturned you are not subtle or French enough to pull it off . Please stop .\n',
#  "Wtf my sister used all the makeup remover cloths and she doesn't even use makeup .\n",
#  'Not a huge fan of long bus rides\n',
#  "@colbertlateshow Yeah yeah great Halloween story Jon, you're a regular Spaulding Gray. \n",
#  'Teahouse explosion in Khuzestan kills four people |RZ | #Iran #IranElection\n',
#  'Respect yourself enough to walk away from anything that no longer serves you , grows you , or makes you happy . \n',
#  'Please reply to mine ! on instagram\n',
#  'Smoke free agent event at mampang park .\n',
#  '"@FoxNews @realDonaldTrump ^SO JUST SHUT UP TRUMP, AND STOP ACTING LIKE YOU DIDNT KNOW WHO SHE WAS FOR NEARLY 30 YEARS ""YOU HAVE NO CLUE"" "\n',
#  'Apple and Blackberry should team up and make a phone called The Pie . \n',
#  "Like don't play games with me I don't have time for it 😒 \n",
#  'the fact that you can hear everyone singing gives me the chills , this is beautiful\n',
#  "@Awkwerdly I've woken up with sore knuckles when there was no fight . Hahaa that's the worst .\n",
#  '"Rob always scaring me 😂 😂 😂 😂 he always texting me outta nowhere like "" we need to talk "" and then telling me something that\'s not serious at all"\n',
#  '*blinks* weekend is over \n',
#  "Can't wait for high school season ⚽️ ❤️\n",
#  'Lol I swear #WorthTheWait\n',
#  '@KevinMalka1 ... yeah , right ... okay ... I believe you ... #not \n',
#  'The smell of freshly washed comforter . Wuuuu Im in dreamland\n',
#  'RT If you allow your genetics to determine your life , it simply means blood rules , not the brain . \n',
#  'Why do cats lick themselves ? 😂 😂 😂 my cat is licking herself on my bed haha\n',
#  '@mylovetroian no worries :) im glad you are okay\n',
#  '@LisaTeMorenga research shows that a huge barrier to cycling is rain . I wonder if there are not direct interventions we could implement . \n',
#  "I'm just tryna see JB cuz I've been a fan since literal day 1 and all u bandwagon hoes wanna talk like u even know my struggle :((((\n",
#  '@kumailn Can only speak for myself , but yes I would call anyone who did that an idiot .\n',
#  'We Are playing brilliant ! They chose the right match to play their best football !\n',
#  '@justin_burl You look awesome best bro\n',
#  "If you go shopping at Walmart and no one stares at you as you walk by , you're one of them . \n",
#  "Kids with special needs are not weird or odd . They only want what everyone else's wants --to be accepted ! Can I\n",
#  'Really looking forward to football this weekend !\n',
#  "It's dead ass still hot down here . It's still 70 degrees out right now lol .\n",
#  'RT Celebs become more popular after they die #caseofali \n',
#  'If opposites attract , the ultimate life strategy is to be a complete loser . \n',
#  'So out of shape , Internet Explorer could probably run faster than me . \n',
#  "@realDonaldTrump don't apologize just start acting serious ignore the bullshit focus on winning like you say so great win and win and win!!! \n",
#  'Cant wait to get back to nice hot sunny England\n',
#  "Woohoo I can't wait till pantomime ... Like sitting in a box listening for the right sounds cues ... Fun fun fun ... Not really \n",
#  '@AdelaineMorin BUT I HAVE TO DO MY HOME WORK 😭 😭 😭\n',
#  '#themaninthehighcastle not only #entertains it fosters #deepthought and makes you reconsider want we this of as ethical .\n',
#  "@fouseyTUBE I'm working on an art work for you , it's based on the depression subject . You will love it , can you please DM me ! #bruhbruhs \n",
#  '"@colbertlateshow I wonder if stop and frisk would be received better if the officer exclaimed, ""Wow! Have you lost weight?"""\n',
#  'What classes do you take at Hogwarts ! ?i love you ❤️ ❤️ @ShawnMendes @Shawn_Access #RevisitedAtMidnight \n',
# ...
#  'Nothing like kicking a dog when down .. what about thsds not yet receiving sp ! Have some years to wait . ! \n',
#  'I LOVE @AllTimeLow SO FUCKING MUCH AND I HOPE THAT THEY HAVE A SUPER FUN NIGHT IM ALSO REALLY REALLY SORRY ABOUT THEIR FRIEND PASSING\n',
#  "Someone will always have something to say about you or your relationship . But it's your life . It only matters what you think .\n",
#  'Girl , I like you so much , I might even let you hold my phone ... some day , while its locked \n',
#  "@burlivesleftnut @Chellie2shoes @falconvein I'm supposed to be watching a tv show right now so I can't respond to ur dumb videos\n",
#  "I hate mosquitoes ! I mean , I know I'm delicious but damn .\n",
#  'Love love love puking #not \n',
#  "I'm pleased to say that I just used some germ -X and got rid of 99 . 9% of germs on both my hands and probably got them back while typing this \n",
#  'Thanks to you @Nerdy_Rainbows my cd #Passion has hit 100 . 000 plays . I appreciate your support :)\n',
#  "Hah ! That's awesome ! Two weeks of no laundry to do . Sweet .\n",
#  "I'm a bomb girlfriend . I make your happiness a priority & I dont give up on you even when I'm angry . I'm your #1 fan all the time .\n",
#  "RT Everytime I see a post that I can relate to , I think *Thank God ! I'm not the only one . Whew !* #SOML \n",
#  '@AnthonyDiComo And far more important ! #NOT \n',
#  'When you become so invested in a show that you wish your life could turn out just like that . Thank you #TheOffice for everything #muchlove\n',
#  'I agree but I think ai would be able to do just enough make every shot difficult\n',
#  '@DrawCaith yay , we can be super awkward together \n',
#  'My modeling paperwork finally came in ! 😂 😂 😂 #SarcasticTweet \n',
#  '@CarmineZozzora @LindaSuhler Let Syria go to hell , and let his wicked witch blow up Libya for no good reason .\n',
#  "@amarksdaspot I'm determined to make 2016 the year that I'm a morning person bc I do love being up early it just never happens \n",
#  'My allergies plus my lack of sleep last night are going to make for a great day today ! \n',
#  'New Rings collection #Tomorrow ?\n',
#  "Works closed Thursday and Friday so I don't have school or work those days . So happy 😍\n",
#  '@MirandaCosgrove It has been such an honor to watch such amazing work from a talented actress like you Miranda Cosgrove! You are amazing!\n',
#  'Going to attempt to sleep early today\n',
#  "@realDonaldTrump cancelling 3 campaign events ? Perhaps he's not well or doesn't have the stamina . Have to question his health .\n",
#  'adele is one of the few humans who get hyped up and talked about and raved over that really truly deserve every second of it . #obsessed\n',
#  'My best friends wow Imy girls\n',
#  "How to get a woman mad in 2 easy steps :1 . Take a picture of her . 2 . Don't show it to her . \n",
#  'Unrest in Northern Mali Has Devastated Tourism Industry\n',
#  'I love taking naps on my day off 😴 \n',
#  'I love the smell of freshly roasted coffee in coffee shops ❤️ ☕️ . It gets my creativity going !\n',
#  'The difference between what you told me and the actual truth is just amazing . #pissedoff \n',
#  'Bc going to CVS @ 1130 in pajamas and slides to get sleep & sinus medicine is what I had in mind for tonight #NOT #ThisIsAwful \n',
#  'Everyone was making comments about how big my butt was . awwkkkk\n',
#  '"Everybody has a girlfriend and a boyfriend , and I\'m over here like "" I love food "" "\n',
#  "Lego's Success Leads to Competitors and Spinoffs - New York Times\n",
#  "OMG LOL no one is my master ... lol ... i can't take it so funny sorry .\n",
#  'A great benefit of serving brunch is being able to pack away food for dinner #PoorAndHungry\n',
#  '@realDonaldTrump Feel bad for all the black voters out there who have once again become victims to the democratic party .\n',
#  "If you're #not in my #corner then your an #opposition ... #RNS \n",
#  "I agree :-) #tomiho's solid fan\n",
#  'Eternity - Epic Cinematic Trailer by @jonwmusic - Cinematic/Filmscore #Filmmaking #RoyaltyFreeMusic\n',
#  '@VickyPattison I actually love the saying buzzing like a old fridge 💁💁\n',
#  'I love you in a bipolar way because I hate you . \n',
#  "@JackAllTimeLow that's awesome . Wish I could be there . Miss you dudes !\n",
#  "@RealSkipBayless he's prob better than Romo . Every year same ol story . Time to move on . Best chances are behind them . Go get #JohhnyFootball \n",
#  'In a paralel alternate universe , my cat and my dog have jobs and I chill at home . \n',
#  '@camerondallas lol it is a phrase that my mom all the time says, have a great night! i love you .\n',
#  "@USATODAY FAKE! , that's all I need to know , another LIE of LIARS \n",
#  "If you don't know the difference between your and you're , your an idiot . \n",
#  "It's totes cute when you have a boyfriend but still sleep with your ex 😄 #not \n",
#  'Hit the gym , now seeing a movie . Great start to the day\n',
#  '@derehamtown Another sleepy Wednesday at work after another Dereham Cup win on penalties #CupMagic #Not GoodForTheTicker \n',
#  'Kill them with kindness 😊 😊 😊 \n',
#  "how can you be so stupid to do that , if you think it's cool to do that shit , it's not , you look like a fucking idiot .\n",
#  'having long hair is the most annoying and wonderful thing ever \n',
#  '"A shopping cart with 8 "" freebies "" and a whopping total of AU $70 just for postage ? #yeahright #noway #mademelaugh "\n',
#  "it's a good feeling especially when you win the game the way we did , playing strong for 60 and staying patient\n",
#  '18:18 Nobody loves me Nobody is great . #sadbuttrue #maybe #not #sad \n',
#  "If Gabe Kapler is named the Dodgers ' new manager , the bandwagon is gonna tip over with thirsty ass hoes .\n",
#  '@FoxNews @IngrahamAngle Hillary Clinton is a failure and needs to admit that to the world . \n',
#  "@x_vins awooo I'm shitting it . Reply to my whatsapp babe #rejected\n",
#  'Honey ! Great news . I could charge my new phone to the account and I can then pay it in January when I have the money from school ! ❤️\n',
#  "I ordered a drink and didn't get id'd ✌️ #yeahright #oldwoman \n",
#  '@PSNKlair88 very fun , very cool , not really any story but overall a very fun game ! \n',
#  "RT If you can be sarcastic in 140 character , boy don't we have Twitter just for you ? \n",
#  'LasVegasSun : Police : Victims restrained inside house ; fire intentionally set #lasvegas\n',
#  "Literally love being talked about when I'm not there . 😈😝 😘 @CTR_Monroe Thanks homie . 😂 \n",
#  "I hate letting my anger get the best of me . It's a rare slip up . But it happens .\n",
#  '@realdonaldtrump giving health insurance companies control will not create lower rates.we will all have to be on Medicaid.\n',
#  "that's cool , dangelos , take your time making my food ... it's not like I have a time limit for my break or anything ... #annoyed \n",
#  'And sometimes someone plugs a router in and leaves for the weekend not knowing they created a resource conflict w the main network drive .\n',
#  '@LittleMix Secret love song ft Jason Derulo is my absolute fave song at the mo !\n',
#  '@lovedbylashon I CHOOSE to honor my husband #NOT because I am weak BUT because I am strong #Mycrazylifeasanavywife \n',
#  "#TGIF the best day of the week .. So happy things are started to shift in a better direction .. ✌️ 😎2hits & I'm floating 2 success #TeamKUSH\n",
#  'Everybody has the power to make someone else happy . Some do it by entering the room , while some do it by leaving . \n',
#  "@acidicccats they're great though I love Crash Course . I used it to review for my AP Bio exam 😂 \n",
#  "Today I admit that I don't know how to read people ... its a #mean #selfish world #trust nobody #not my kind of place #reality #fool I am 😠 \n",
#  'So excited to wake up at 5 a . m . tomorrow ! \n',
#  'So hot down here in Sydney today I was practically a hydro electricity power station .\n',
#  '"New to the ECAS Research Office ? Join us at noon next Thurs . in 211 WDB to learn "" Who We Are and What We Offer ! "" #eberlyresearchersBB"\n',
#  '@manizhe admit it that u were fooled by BB &RimiSen pls dont insult the intelligence of audience . Respect the show . @BiggBoss #bb9\n',
#  '@gueorgui @aqworks Oh shit , wow ! And yes , certainly one of the best bunch of people you ever could have worked with .\n',
#  'Im watching the Halloween bobs burgers and its even scaring me wth\n',
#  "And I'm so excited . Like .. Bruh . If You was sleep wake up . 😭 😭 😭 😭 😭 😭 😭 \n",
#  'Looking for chiropractic associate in sports medicine who wants a great 40 year career . Direct message me for details\n',
#  'Hey you have a cute smile — Thank you very much ☺️\n',
#  'That awkward moment when you can remove 95% of her beauty with a wet towel . \n',
#  '@ComedyCentral stop fucking playing Step Brothers this is like the 5th night in a row , its safe to say everyone has seen it .\n',
#  "You'll never guess what movie is on @AMC_TV right now ... INDEPENDENCE DAY ? ! YES !\n",
#  "If y'all don't roast tf out each other y'all ain't really friends \n",
#  "@CricNSWBreakers keeping track of the game while I'm on the golf course ... great total to defend , well done to Al and Ellyse\n",
#  'Love hearing the construction noise right beside our #office windows #NOT \n',
#  'kids can drown in sinks , tubs , toilets and even half-filled buckets ! Make November a water-safe month !\n',
#  'Aww @J_Smutz parked next to me ! #not\n',
#  "Katsina : Gov't Spent N200m In Fighting Rustling As 49 Suspects Arrested , 2 , 677 Animals Recovered #katsinapost\n",
#  "lmao awesome RT WOW ! LOL ! RT Best HS banner I've ever seen .\n",
#  'really excited to see my gfs tonight 😍 😭 @Brooke_bronson @allyse_F\n',
#  'if you agree with @tedcruz that @POTUS should protect this nation and not insult millions of Americans #CruzCrew\n',
#  "I can't wait until I can once again cough or sneeze without peeing my pants a little 😭 #preggoproblems \n",
#  '@Michael5SOS happy birthday , I love you x 😁✌\n',
#  'I love English so much I would rather take a million English classes than 1 math class bye \n',
#  'Their is very little one can do for lead poison . We owe the pukes nothing . Their joy human ! \n',
#  "@YouTube I don't understand the new YouTube rules kid's don't need to hide from bad language some I'm sorry but it needs to be said \n",
#  'somethings not right . Im abt to go thru his papers rn\n',
#  'i hate shaving my legs but I love having shaved legs u feel me\n',
#  'Waifs and strays thine subtle influence pistil : ZbJmWKNhv\n',
#  '@_chloehoang wot is this kindness ... Are you gonna kill me tmw or something .. ? ! \n',
#  '"do you ever just look at someone and think "" wow , let me take off your pants ? """\n',
#  'We all have that one person who we wished we never gave our phone number to ... #Ted\n',
#  "Always remember the three R's of life :1) Respect for yourself 2) Respect for others 3) Radiation gives you superpowers \n",
#  'Genuinely never laughed so much at an interview ever\n',
#  "im so stressed about this interview tomorrow that im just not going to go because i don't need the anxiety\n",
#  "really hasn't got too cold yet ... I'm shocked 😂\n",
#  '@FoxNews Surely you know about LAX shooter . Why zero coverage ? \n',
#  '#cricket UPDATE 1 -Cricket -Dazzling Buttler , Roy lead England to series win : Nov 20 (Reuters ) - Jos Butt ... #sport\n',
#  "You're a bitch You're a b You're a You're You Yo Y You You're You're a You're a bi You're a bitch Oh , you're still a bitch\n",
#  "My sister is watching me tinder and she thinks it's fascinating/hilarious Being married must suck rn\n",
#  'So now guess whos covered in hives and rashes and welts from itching 😰 \n',
#  'how i stop making myself feel like shit 100% of the time \n',
#  '@billmaher @HillaryClinton @vicenews When the USS America goes down , who stands at the helm ? @realDonaldTrump will be cause with immunity !\n',
#  '*Me when I turn 18* Parents : Do this . Me : Dobby has no master . Dobby is a free elf . \n',
#  '@Holypants1 Math is hit and miss for me . As for proofs that was the only thing I liked in Geometry . I love it to death ! \n',
#  "Already fucking stressed I don't need your shit\n",
#  "You know that thing called sleep .. yeah that thing where you're knocked out for a few hours ... can I have some of that ? It would be great \n",
#  '@FBI @NewYorkFBI @FBIWFO @FBILosAngeles you seriously let pedophiles walk,do no one of you have children?@NYPDnews… https://t.co/pg6T71ODUY \n',
#  'car rides without music = awkward \n',
#  'Is it true that pain is beauty ? Does a new face come with a warranty ? Will a pretty face make it better ?\n',
#  'RT Cop :Do you know how fast you were going ? Me :My snapchat selfie says 45 Cop :LMAO ADD ME \n',
#  'espn is disapionted that they didnt get the #CFL game tonight . it is monday night after all #mnf\n',
#  'myron butler & levi - set me free #nowplaying #listenlive\n',
#  '"RT Space bar be like , "" Shift , please , I need my space . "" "\n',
#  "lauren singing i don't give a fuck at the top of her lungs lmao this is so funny\n",
#  '@homesweethomegn What an absolute amazing place . Nice food and such nice staff . Will be back again . 😊\n',
#  'The scar on my bottom lip has never pissed me off more than it has today . Shit is annoying . So soft . So supple . #not \n',
#  'Dead car battery , really not impressed right now #notagoodstart #literally \n',
#  "It's not even December yet but I don't care - CHRISTMAS IS ALMOST HERE AND I CANNOT WAIT . 29 days until I'm back in sunny Yorkshire 3\n",
#  "@sujeeeen if it's as fucked up as the comic , it should be great watch\n",
#  '@alien_puke I love you Celeste thank you 😁 😍 😘 ❤ ❤ ❤ ❤ ❤ ❤\n',
#  "A solid 50% of snapchat this week has been all about #Rivalry151 and there's nothing like the Rivalry to make me miss college \n",
#  "@BarkM302 @NissanUSA I don't want to see a Nissan ad until they make a successor to the 240sx .\n",
#  'Wet and windy in France , but the #pilgrimage2paris is in good spirits & met the Archbishop of Rouen this afternoon . \n',
#  'RT Fat girls should be socially accepted Fat boys should go to gym and have abs . \n',
#  'Come home to everyone asleep and no food \n',
#  "Women's rights & Islam cannot coexist .\n",
#  'And since I forgot to turn off before James , theres SPD chasing a man in a power scooter weaving thru traffic . #entertainmentdistrict\n',
#  '@fairuzrahman yeah very very true . Its that frustration mainly . Sigh . A lil demotivating too kadang2 . Kena release cara baik :( *hugs *\n',
#  'MY FAVRIT SASSY FEMALE VOCALIST , DANCER , ATHLETE . MUMMY 3 PINK 3\n',
#  "I guess sometimes I'm just gonna be covered in hives and have no idea what's causing them \n",
#  'How do u squish a cupcake for no reason . I am devastated\n',
#  "@barstoolWSD I think it died with the old site . it was great though . there's a lot to be talked about with regards to peeing in sinks\n",
#  '@FisherBurton @MMFlint yeah @billmaher sure spreads hate against them , he is mentally sick when it comes to Muslims .\n',
#  "@CNN @TaraSetmayer WTF!? Hillary collapses this morning and #CNN is bashing Trump for it LOL?!! He hasn't even said a word about it! #idiots\n",
#  'i love making other people happy it makes me happy seeing other people happy \n',
#  '@realDonaldTrump where u have a seat at the right hand of that father\n',
#  "@ShrendanBanahan @bourney20 I love the arguments different point of views isn't a bad thing \n",
#  '@yoncetmh I Cant Wait For Finding Nemo 😹😹✔️\n',
#  'To the guy who decided to drive in my lane going the opposite direction , I would love to commend you on how great of a driver you are . #NOT \n',
#  'Lol it be so cutee when my baby talks to my belly every night just so she will move 😍 😍 \n',
#  '@maddie_w82 hope you had a solid day ! #stay #swaggy #not #faggy @Caro_Wade \n',
#  'Glad that bitch dead ! #HTGAWM \n',
#  "You shouldn't never doubted me !\n",
#  'Hey guys , just a heads up from Australia . Monday was shit .\n',
#  "@MailOnline Ever think that might offensive to people in other countries ! Stop throwing this in people's faces . Not at the Olympics 👎🏼 \n",
#  'Sometimes paper cuts are deeper than they appear . #deepthought\n',
#  ...]

# %%
df = pd.DataFrame({"text": sarcasm})

# %%
df
# Out:
#                                                     text
# 0      It feels like just a few days ago it was the l...
# 1      I love my mom . No matter what we go through ,...
# 2                Bump that music ... #imtryingtosleep \n
# 3      Mexican and black jokes are pretty much the sa...
# 4                          How to find work you love :\n
# ...                                                  ...
# 51184  RT My EX had one very annoying habit . Breathi...
# 51185  Some days you're the Titanic , some days you'r...
# 51186  Congrats on the release of 25 @Adele , let's h...
# 51187               doing my favorite thing .. crying \n
# 51188  @TheSupremEC0URT roommate of the week really l...
#
# [51189 rows x 1 columns]

# %%
df['text']
# Out:
# 0        It feels like just a few days ago it was the l...
# 1        I love my mom . No matter what we go through ,...
# 2                  Bump that music ... #imtryingtosleep \n
# 3        Mexican and black jokes are pretty much the sa...
# 4                            How to find work you love :\n
#                                ...
# 51184    RT My EX had one very annoying habit . Breathi...
# 51185    Some days you're the Titanic , some days you'r...
# 51186    Congrats on the release of 25 @Adele , let's h...
# 51187                 doing my favorite thing .. crying \n
# 51188    @TheSupremEC0URT roommate of the week really l...
# Name: text, Length: 51189, dtype: object

# %% [markdown]
# ## Clean, Prepare and vectorize the data

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
swords = stopwords.words('english')
wnl = WordNetLemmatizer()

# %%
def lemmatize(word):
    tag = pos_tag([word])
    pos='n'
    if tag[0][1].startswith('N'):
        pos = 'n'
    elif tag[0][1].startswith('V'):
        pos = 'v'
    elif tag[0][1].startswith('R'):
        pos = 'r'
    elif tag[0][1].startswith('J'):
        pos = 'a'
    
    return wnl.lemmatize(word, pos=pos)

# %%
def clean_txt(sent):
    tokens1 = word_tokenize(sent)  # Step-1. Tokenize the text
    tokens2 = [token for token in tokens1 if token.isalnum()]  # Step-2 Remove the punctuations
    tokens3 = [token.lower() for token in tokens2 if token.lower() not in swords]  # Step-3 Remove stopwords
    tokens4 = [lemmatize(token) for token in tokens3]  # step-4 Remove the suffixes
    return tokens4

# %% [markdown]
# ## TF*IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf = TfidfVectorizer(analyzer=clean_txt)

# %%
X_new = tf.fit_transform(df['text'])

# %%
X_new
# Out:
# <51189x42845 sparse matrix of type '<class 'numpy.float64'>'
# 	with 421419 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Create the clusters

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(random_state=0, n_clusters=2)

# %%
km.fit_predict(X_new)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
set(km.labels_)
# Out:
# {0, 1}

# %%
km.inertia_   # Sum of squared errors
# Out:
# 50805.12881339269

# %% [markdown]
# ## Elbow Method

# %%
sse = []
for k in range(1,16):
    km = KMeans(n_clusters=k,random_state=0)
    km.fit_predict(X_new)
    sse.append(km.inertia_)

# %%
plt.xlabel('Value of K')
plt.ylabel('SSE')
plt.grid()
plt.xticks(range(1, 16))
plt.plot(range(1,16),sse,marker='o',color='r')

# %% [markdown]
# ## Build the K-means clustering algorithm with 2 clusters.

# %%
km = KMeans(n_clusters=2, random_state=0, n_init='auto')

# %%
labels = km.fit_predict(X_new)

# %%
labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ## Show the tweets with 0 and 1 labels respectively.

# %%
zero = df[labels == 0]
one = df[labels == 1]

# %%
zero  # Not Sarcastic
# Out:
#                                                     text
# 9      When people give me directions I tend to conce...
# 22     "me liking your selfie could either mean "" th...
# 24     "You took a piece of me and I let you . And th...
# 27     Love means never being able to like another gi...
# 76     @realDonaldTrump If that means you promise to ...
# ...                                                  ...
# 51064  "Justin Bieber got 100,000 retweets for tweeti...
# 51069  RT Kicking into empty air sitting on a broomst...
# 51118  @CNNPolitics @Aleksander_Lee @Deena_CNN I have...
# 51127  Funny we never hear about that level of work e...
# 51135  @NBCNews I never thought so before, but Obama ...
#
# [1935 rows x 1 columns]

# %%
one  # Sarcastic
# Out:
#                                                     text
# 0      It feels like just a few days ago it was the l...
# 1      I love my mom . No matter what we go through ,...
# 2                Bump that music ... #imtryingtosleep \n
# 3      Mexican and black jokes are pretty much the sa...
# 4                          How to find work you love :\n
# ...                                                  ...
# 51184  RT My EX had one very annoying habit . Breathi...
# 51185  Some days you're the Titanic , some days you'r...
# 51186  Congrats on the release of 25 @Adele , let's h...
# 51187               doing my favorite thing .. crying \n
# 51188  @TheSupremEC0URT roommate of the week really l...
#
# [49254 rows x 1 columns]

# %%
one['text'].iloc[4]
# Out:
# 'How to find work you love :\n'

# %%
print("'Cluster-0:", len(zero))
print("'Cluster-1:", len(one))
# Out:
# 'Cluster-0: 1935
# 'Cluster-1: 49254

# %% [markdown]
# ## Find and print sarcastic and non-sarcastic tweet’s top 10 words each.

# %% [markdown]
# ## Wordcloud

# %% [markdown]
# ### Zeroth cluster

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud().generate(' '.join(zero['text']))
plt.figure(figsize=(16,9))
plt.title('Zeroth Cluster')
plt.imshow(wc);

# %%
from nltk import FreqDist

# %%
swords = stopwords.words('english')

# %%
new = ' '.join(zero['text'])
clean = [x for x in word_tokenize(new) if x.lower() not in swords and x.isalpha()]
freq = FreqDist(clean)
print("Top 10 words from non-sarcastic tweets: ")
freq.most_common(10)
# Out:
# Top 10 words from non-sarcastic tweets:
# [('never', 975),
#  ('trying', 337),
#  ('try', 312),
#  ('like', 176),
#  ('love', 165),
#  ('Never', 151),
#  ('get', 147),
#  ('much', 142),
#  ('people', 133),
#  ('know', 99)]

# %% [markdown]
# ### First Cluster

# %%
wc = WordCloud().generate(' '.join(one['text']))
plt.figure(figsize=(16,9))
plt.title('First Cluster')
plt.imshow(wc);

# %%
new = ' '.join(one['text'])
clean = [x for x in word_tokenize(new) if x.lower() not in swords and x.isalpha()]
freq = FreqDist(clean)
print("Top 10 words from sarcastic tweets: ")
freq.most_common(10)
# Out:
# Top 10 words from sarcastic tweets:
# [('love', 4466),
#  ('like', 3698),
#  ('day', 2457),
#  ('get', 2350),
#  ('people', 2089),
#  ('RT', 1774),
#  ('good', 1727),
#  ('great', 1699),
#  ('one', 1694),
#  ('u', 1679)]
